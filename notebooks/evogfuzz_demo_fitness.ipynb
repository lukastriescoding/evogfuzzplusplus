# %% [markdown]
# # EvoGFuzz: An Evolutionary Approach to Grammar-Based Fuzzing
#
# **EvoGFuzz** stands for *evolutionary grammar-based fuzzing*. This approach leverages evolutionary optimization techniques to systematically explore the space of a program's potential inputs, with a particular emphasis on identifying inputs that could lead to exceptional behavior. With a user-defined objective, EvoGFuzz can adapt and refine the input generation strategy over time, making it a powerful tool for uncovering software defects and vulnerabilities.
#
# Efficient detection of defects and vulnerabilities hinges on the ability to automatically generate program inputs that are both valid and diverse. One common strategy is to use grammars, which provide structured and syntactically correct inputs. This approach leads to the concept of grammar-based fuzzing, where fuzzing strategies are guided by the rules defined within the grammar.
#
# A further enhancement to this concept is probabilistic grammar-based fuzzing, where competing grammar rules are associated with probabilities that guide their application. By carefully assigning and optimizing these probabilities, we gain considerable control over the nature of the generated inputs. This enables us to direct the fuzzing process towards specific areas of interest—for example, those functions that are deemed critical, have a higher propensity for failures, or have undergone recent modifications.
#
# In essence, EvoGFuzz represents a potent blend of evolutionary optimization and probabilistic grammar-based fuzzing, poised to reveal hidden defects and vulnerabilities in a targeted and efficient manner.

# %% [markdown]
# ## Fuzzing a Program

# %% [markdown]
# Our program under investigation is `The Calculator`. This program acts as a typical calculator, capable of evaluating not just arithmetic expressions but also trigonometric functions, such as sine, cosine, and tangent. Furthermore, it also supports the calculation of the square root of a given number.

# %%
import math

def calculator(inp: str) -> float:
    """
        A simple calculator function that can evaluate arithmetic expressions 
        and perform basic trigonometric functions and square root calculations.
    """
    return eval(
        str(inp), {"sqrt": math.sqrt, "sin": math.sin, "cos": math.cos, "tan": math.tan}
    )

# %%
from debugging_framework.input.oracle import OracleResult

# %%
# Make sure you use the OracleResult from the debugging_framework library
from debugging_framework.input.oracle import OracleResult

def oracle(inp: str):
    """
    This function serves as an oracle or intermediary that catches and handles exceptions 
    generated by the 'calculator' function. The oracle function is used in the context of fuzz testing.
    It aims to determine whether an input triggers a bug in the 'calculator' function.

    Args:
        inp (str): The input string to be passed to the 'calculator' function.

    Returns:
        OracleResult: An enumerated type 'OracleResult' indicating the outcome of the function execution.
            - OracleResult.PASSING: Returned if the calculator function executes without any exception or only with CalculatorSyntaxError
            - OracleResult.FAILING: Returned if the calculator function raises a ValueError exception, indicating a potential bug.
    """
    try:
        calculator(inp)
    except ValueError as e:
        return OracleResult.FAILING
    
    return OracleResult.PASSING

# %% [markdown]
# We can see this in action by testing a few initial inputs:

# %%
initial_inputs = ['sqrt(1)', 'cos(912)', 'tan(4)']

for inp in initial_inputs:
    print(inp.ljust(20), oracle(inp))
# Out:
# sqrt(1)              PASSING
# cos(912)             PASSING
# tan(4)               PASSING

# %% [markdown]
# The following code represents a simple context-free grammar for our calculator function. This grammar encompasses all the potential valid inputs to the calculator, which include mathematical expressions involving square roots, trigonometric functions, and integer and decimal numbers:

# %%
from debugging_framework.types import Grammar
from debugging_framework.fuzzingbook.grammar import is_valid_grammar

CALCGRAMMAR: Grammar = {
    "<start>":
        ["<function>(<term>)"],

    "<function>":
        ["sqrt", "tan", "cos", "sin"],
    
    "<term>": ["-<value>", "<value>"], 
    
    "<value>":
        ["<integer>.<integer>",
         "<integer>"],

    "<integer>":
        ["<digit><integer>", "<digit>"],

    "<digit>":
        ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
}
    
assert is_valid_grammar(CALCGRAMMAR)

# %% [markdown]
# ### Incorporating Custom Fitness Functions
#
# The fitness function plays a crucial role in guiding the evolution process of our fuzzing inputs. A well-crafted fitness function can effectively direct the search towards the most promising regions of the input space.
#
# To create your own fitness function, define a function that takes an `Input` instance and returns a float value. The return value represents the 'fitness' of the given input, with higher values indicating better fitness. Here is a simple template:
#
# ```python
# from evogfuzz.input import Input
#
# def fitness_function_XYZ(inp: Input) -> float:
#     # Implement your fitness function here.
#     return 0.0
# ```

# %% [markdown]
# For instance, suppose we're interested in inputs that invoke the cosine function in our calculator. We could define a fitness function `fitness_function_cos` that assigns a high fitness value to inputs containing 'cos'. (**Note that this might not be the best fitness function to find new expcetions.**)

# %%
from evogfuzz.input import Input

def fitness_function_tree(inp: Input) -> float:
    node, children = inp.tree # derivation tree; node -> children; example: <start> -> <function>(<term>)... 
    print(node, children)
    return 0

# %% [markdown]
# Once your fitness function is defined, you can incorporate it into the `EvoGFuzz` instance by passing it as the `fitness_function` argument.

# %%
from evogfuzz.evogfuzz_class import EvoGFuzz

epp = EvoGFuzz(
    grammar=CALCGRAMMAR,
    oracle=oracle,
    inputs=initial_inputs,
    fitness_function=fitness_function_tree,
    iterations=10
)

found_exception_inputs = epp.fuzz()

print(f"EvoGFuzz found {len(found_exception_inputs)} bug-triggering inputs!")

for inp in found_exception_inputs:
    print(str(inp))
# Out:
# <start> [DerivationTree('<function>', (DerivationTree('sqrt', (), id=23954),), id=23955), DerivationTree('(', (), id=23953), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=23948),), id=23949),), id=23950),), id=23951),), id=23952), DerivationTree(')', (), id=23947)]
# <start> [DerivationTree('<function>', (DerivationTree('sqrt', (), id=23646),), id=23647), DerivationTree('(', (), id=23645), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=23640),), id=23641), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=23637),), id=23638),), id=23639)), id=23642),), id=23643),), id=23644), DerivationTree(')', (), id=23636)]
# <start> [DerivationTree('<function>', (DerivationTree('cos', (), id=24082),), id=24083), DerivationTree('(', (), id=24081), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=24076),), id=24077),), id=24078),), id=24079),), id=24080), DerivationTree(')', (), id=24075)]
# <start> [DerivationTree('<function>', (DerivationTree('sqrt', (), id=24461),), id=24462), DerivationTree('(', (), id=24460), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=24455),), id=24456), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=24452),), id=24453), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=24449),), id=24450),), id=24451)), id=24454)), id=24457),), id=24458),), id=24459), DerivationTree(')', (), id=24448)]
# <start> [DerivationTree('<function>', (DerivationTree('sqrt', (), id=23505),), id=23506), DerivationTree('(', (), id=23504), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=23499),), id=23500), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=23496),), id=23497), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=23493),), id=23494), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=23490),), id=23491),), id=23492)), id=23495)), id=23498)), id=23501),), id=23502),), id=23503), DerivationTree(')', (), id=23489)]
# <start> [DerivationTree('<function>', (DerivationTree('tan', (), id=23590),), id=23591), DerivationTree('(', (), id=23589), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=23584),), id=23585), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=23581),), id=23582), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=23578),), id=23579),), id=23580)), id=23583)), id=23586),), id=23587),), id=23588), DerivationTree(')', (), id=23577)]
# <start> [DerivationTree('<function>', (DerivationTree('cos', (), id=23692),), id=23693), DerivationTree('(', (), id=23691), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=23686),), id=23687), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=23683),), id=23684),), id=23685)), id=23688),), id=23689),), id=23690), DerivationTree(')', (), id=23682)]
# <start> [DerivationTree('<function>', (DerivationTree('tan', (), id=24357),), id=24358), DerivationTree('(', (), id=24356), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=24351),), id=24352), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=24348),), id=24349), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=24345),), id=24346), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=24342),), id=24343), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=24339),), id=24340),), id=24341)), id=24344)), id=24347)), id=24350)), id=24353),), id=24354),), id=24355), DerivationTree(')', (), id=24338)]
# <start> [DerivationTree('<function>', (DerivationTree('tan', (), id=
DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=44681),), id=44682),), id=44683)), id=44686)), id=44689)), id=44692)), id=44695)), id=44698)), id=44701)), id=44709),), id=44710), DerivationTree(')', (), id=44680)]
# <start> [DerivationTree('<function>', (DerivationTree('cos', (), id=43937),), id=43938), DerivationTree('(', (), id=43936), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43931),), id=43932), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43928),), id=43929), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43925),), id=43926), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43922),), id=43923), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43919),), id=43920), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=43916),), id=43917),), id=43918)), id=43921)), id=43924)), id=43927)), id=43930)), id=43933), DerivationTree('.', (), id=43915), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43912),), id=43913), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=43909),), id=43910),), id=43911)), id=43914)), id=43934),), id=43935), DerivationTree(')', (), id=43908)]
# <start> [DerivationTree('<function>', (DerivationTree('cos', (), id=45152),), id=45153), DerivationTree('(', (), id=45151), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=45146),), id=45147), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=45143),), id=45144), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=45140),), id=45141), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=45137),), id=45138),), id=45139)), id=45142)), id=45145)), id=45148),), id=45149),), id=45150), DerivationTree(')', (), id=45136)]
# <start> [DerivationTree('<function>', (DerivationTree('tan', (), id=44801),), id=44802), DerivationTree('(', (), id=44800), DerivationTree('<term>', (DerivationTree('-', (), id=44798), DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=44794),), id=44795), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=44791),), id=44792), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=44788),), id=44789), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=44785),), id=44786),), id=44787)), id=44790)), id=44793)), id=44796), DerivationTree('.', (), id=44784), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=44781),), id=44782), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=44778),), id=44779), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=44775),), id=44776), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=44772),), id=44773), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=44769),), id=44770), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=44766),), id=44767), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=44763),), id=44764),), id=44765)), id=44768)), id=44771)), id=44774)), id=44777)), id=44780)), id=44783)), id=44797)), id=44799), DerivationTree(')', (), id=44762)]
# <start> [DerivationTree('<function>', (DerivationTree('cos', (), id=42906),), id=42907), DerivationTree('(', (), id=42905), DerivationTree('<term>', (DerivationTree('-', (), id=42903), DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=42899),), id=42900), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('9', (), id=42896),), id=42897),), id=42898)), id=42901), DerivationTree('.', (), id=42895), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=42892),), id=42893), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=42889),), id=42890),), id=42891)), id=42894)), id=42902)), id=42904), DerivationTree(')', (), id=42888)]
# <start> [DerivationTree('<function>', (DerivationTree('sin', (), id=43271),), id=43272), DerivationTree('(', (), id=43270), DerivationTree('<term>', (DerivationTree('<value>', (DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43265),), id=43266), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43262),), id=43263), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('4', (), id=43259),), id=43260), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43256),), id=43257),), id=43258)), id=43261)), id=43264)), id=43267), DerivationTree('.', (), id=43255), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43252),), id=43253), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('2', (), id=43249),), id=43250), DerivationTree('<integer>', (DerivationTree('<digit>', (DerivationTree('1', (), id=43246),), id=43247),), id=43248)), id=43251)), id=43254)), id=43268),), id=43269), DerivationTree(')', (), id=43245)]
# EvoGFuzz found 80 bug-triggering inputs!
# sqrt(-19111)
# sqrt(-91.14224)
# sqrt(-9121)
# sqrt(-24219219914929)
# sqrt(-21)
# sqrt(-2219.91)
# sqrt(-211.22)
# sqrt(-9.22199)
# sqrt(-29)
# sqrt(-429.9119)
# sqrt(-111.2)
# sqrt(-219121)
# sqrt(-919119.91129)
# sqrt(-11412421)
# sqrt(-1244)
# sqrt(-1911)
# sqrt(-9242142)
# sqrt(-99.9219499)
# sqrt(-2229944)
# sqrt(-949919)
# sqrt(-2919.49)
# sqrt(-1.19221)
# sqrt(-99)
# sqrt(-229)
# sqrt(-49.29222229)
# sqrt(-9221212.412)
# sqrt(-491)
# sqrt(-192.49122222291922)
# sqrt(-11921.994199924)
# sqrt(-1.14941)
# sqrt(-11191119)
# sqrt(-1911.199211)
# sqrt(-2192.1112211)
# sqrt(-412.12419)
# sqrt(-4.99141412242919)
# sqrt(-4.2)
# sqrt(-412)
# sqrt(-149)
# sqrt(-229.1222)
# sqrt(-4129.21414)
# sqrt(-999)
# sqrt(-422219242112.1)
# sqrt(-4.1)
# sqrt(-4212)
# sqrt(-911414999)
# sqrt(-9921)
# sqrt(-11291291)
# sqrt(-211.2999214999)
# sqrt(-21.11)
# sqrt(-1124124.19)
# sqrt(-1)
# sqrt(-11.1)
# sqrt(-9149)
# sqrt(-11191)
# sqrt(-2.11)
# sqrt(-2942499221419999)
# sqrt(-29192.119)
# sqrt(-219)
# sqrt(-11191292)
# sqrt(-14)
# sqrt(-91199499929292241194111)
# sqrt(-9299.1121)
# sqrt(-41)
# sqrt(-244)
# sqrt(-22)
# sqrt(-114)
# sqrt(-1111.1)
# sqrt(-9)
# sqrt(-291991124.2922)
# sqrt(-194)
# sqrt(-1911142)
# sqrt(-1992)
# sqrt(-1.91)
# sqrt(-142)
# sqrt(-2212911.22249)
# sqrt(-1.2911)
# sqrt(-9.11222412)
# sqrt(-9.91241)
# sqrt(-11.941)
# sqrt(-2)

# %% [markdown]
# This way, the evolutionary grammar-based fuzzing process is now guided by your custom fitness function, focusing more on the areas you deem critical.

# %% [markdown]
# #### Evaluating Inputs Based on Custom Fitness Function

# %% [markdown]
# When utilizing a custom fitness function, such as `fitness_function_cos` in our case, we expect inputs containing 'cos' to achieve the highest fitness scores. This is because our fitness function assigns a score of 1.0 to any input that includes 'cos'.
#
# To confirm this behavior, we retrieve all inputs generated during the fuzzing process using the `get_all_inputs()` method and sort these inputs based on their fitness scores.

# %%
all_generated_inputs = epp.get_all_inputs()
all_generated_inputs_sorted = sorted(all_generated_inputs, key=lambda inp: inp.fitness, reverse=True)

# %% [markdown]
# Let's display these sorted inputs along with their fitness scores. The inputs that contain 'cos' should appear first, demonstrating their high fitness value.

# %%
# investigate only the first 20 bug-triggering inputs
for inp in all_generated_inputs_sorted[:20]:
    print(f"{str(inp).ljust(40)} fitness: {inp.fitness}")
# Out:
# sqrt(-43441226)                          fitness: 0
# sqrt(43.48)                              fitness: 0
# sqrt(4.44844491268)                      fitness: 0
# sqrt(91.1)                               fitness: 0
# sqrt(41)                                 fitness: 0
# sqrt(-642216)                            fitness: 0
# sqrt(3)                                  fitness: 0
# sqrt(6382291.122938434442)               fitness: 0
# sqrt(-14.24)                             fitness: 0
# sqrt(-632148)                            fitness: 0
# sqrt(1.3)                                fitness: 0
# tan(6)                                   fitness: 0
# sqrt(-44861426432211332566444.433)       fitness: 0
# tan(1842152)                             fitness: 0
# sqrt(-8)                                 fitness: 0
# cos(24424421)                            fitness: 0
# sqrt(-12.12662)                          fitness: 0
# cos(463)                                 fitness: 0
# sqrt(-92836446934.3)                     fitness: 0
# sqrt(-981394)                            fitness: 0

# %% [markdown]
# The resulting output validates the effectiveness of our custom fitness function. It shows how we can guide the evolutionary grammar-based fuzzing process towards specific regions of the input space, thereby facilitating targeted exploration and bug discovery.
